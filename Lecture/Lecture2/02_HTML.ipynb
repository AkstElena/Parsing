# %% [markdown]
# # Парсинг HTML. BeautifulSoup.

# %% [markdown]
# ### Скрейпинг и парсинг данных одной страницы.

# %%
# Импорт необходимых библиотек
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Путь к странице с данным
website = "https://apteka.ru/category/vitamin-mineral/"

# %%
# GET-запрос к серверу
page = requests.get(website)

# %%
# Проверка статуса ответа сервера
page.status_code
# Out:
# 432

# %%
type(page.text)
# Out:
# str

# %%
type(page.content)
# Out:
# bytes

# %%
# Парсинг данных 
soup = BeautifulSoup(page.content, 'html.parser')

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru">\n\n<head>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport"\n        content="width=device-width, user-scalable=no, height=device-height, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0, viewport-fit=cover">\n    <title>Apteka.ru - С вашего IP замечена подозрительная активность</title>\n    <link rel="preconnect" href="https://fonts.googleapis.com">\n    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>\n    <link href="https://fonts.googleapis.com/css2?family=Source+Sans+Pro:wght@400;600&display=swap" rel="stylesheet">\n    <link rel="icon" href="/static/Favicon.ico" type="image/x-icon">\n    <style>.button,h1,p{font-family:\'Source Sans Pro\';line-height:150%}.button,body{align-items:center}h1,p{font-style:normal}.button:hover,h1{color:#1c257b}.button,.thumb{cursor:pointer}.slider::before,.thumb{box-sizing:border-box;position:absolute}.slider::before,.slider[data-loader],.slider[data-success],.thumb[data-stop]{pointer-events:none}.slider::before,.thumb::before{content:\'\';width:36px;height:36px;top:4px}body{display:flex;justify-content:flex-end;flex-direction:column;text-align:center;padding:20px;min-height:100vh;margin:0;background-color:#fff}footer{margin-top:20vh;margin-bottom:9vh}h1{font-weight:600;font-size:32px;margin:0 0 36px}.button,p{margin:0}p{font-weight:400;font-size:16px}.content>img{max-width:100%;margin-bottom:36px}p small{font-size:12px;color:#999}.button{font-size:14px;color:#4665d7;display:inline-flex;border:0;background:0 0;gap:6px;padding:4px 6px}.copy-icon[hidden]{display:none;visibility:hidden}.copy-icon[hidden]+.success-icon,.slider[data-error] .error,.slider[data-success] .success,.thumb .arrow{display:block}.slider-wrap[aria-hidden] .thumb,.slider[data-error] .arrow,.slider[data-loader] .arrow,.slider[data-success] .arrow,.success-icon,.thumb>img{display:none}.logo{margin-bottom:28px}.social__icon{position:relative;display:inline-block;width:34px;height:34px;border-radius:4px;background-color:#e0e1f3;margin-right:10px;transition:color .25s ease-out}.social__icon:hover{background-color:#c9cbe7}.social__icon:last-child{margin-right:0}.social__icon>img{position:absolute;top:50%;left:50%;transform:translate(-50%,-50%)}@media (max-width:800px){h1{font-size:20px}.content>img{width:220px}footer{margin-top:15vh}}.slider-wrap{margin:24px auto;transition:opacity .25s}.slider-wrap[aria-hidden]{visibility:hidden;pointer-events:none;opacity:0;z-index:-1}.slider-wrap p{margin-bottom:12px;line-height:1.2}.slider{position:relative;width:213px;height:44px;margin:0 auto;border-radius:91px;background:linear-gradient(260deg,rgba(208,229,251,.47) 4.68%,rgba(94,145,200,.36) 99.18%)}.slider::before{right:4px;border:2px dashed rgba(255,255,255,.5);border-radius:50%}.thumb{width:44px;height:44px;top:0;left:0;display:flex;align-items:center;justify-content:center}.thumb:hover::before,.thumb[data-stop]::before{outline-color:#d0d3ea}.thumb:hover::before{animation:.5s gelatine}@keyframes gelatine{from,to{transform:scale(1,1)}25%{transform:scale(.9,1.1)}50%{transform:scale(1.1,.9)}75%{transform:scale(.95,1.05)}}.thumb::before{position:absolute;left:4px;background-color:#fff;border-radius:50%;outline:transparent solid 2px}.thumb>img{position:relative;z-index:1}.thumb>img[hidden]{position:absolute;top:100vh;visibility:hidden;z-index:-1}.thumb .spinner{animation:.5s infinite paused spin}@keyframes spin{from{transform:rotate(0)}to{transform:rotate(360deg)}}.slider[data-loader] .spinner{display:block;animation-play-state:running}</style>\n</head>\n\n<body>\n    <main>\n        <h1>Подозрительная активность!</h1>\n        <div class="content">\n            <img src="/432/static/Suspicious-Cat.png" alt="alert-cat">\n            <p>С вашего IP замечена подозрительная активность</p>\n            <div class="slider-wrap" aria-hidden>\n                <p><small>Чтобы продолжить, зажмите и переместите стрелку до конц ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="telephone=no" name="format-detection"/><style id="critical">body{background:#fff;color:#000;font-family:Source Sans Pro,sans-serif;font-size:100%;font-style:normal;font-weight:400;line-height:1.2}svg{fill:currentColor}.no-select{user-select:none}.rub{font-size:.9em}h1{font-size:2rem}h1,h2{color:#4665d7;font-weight:600;margin:1em 0}h2{font-size:1.5rem}h3{color:#4665d7;font-size:1.25rem;font-weight:600}h3,p{margin:1em 0}b,strong{font-weight:600}.link,a{color:#4665d7;cursor:pointer;outline:0;text-decoration:none;transition:color .25s ease-in-out}.link:not([href]),a:not([href]){cursor:default}.link[aria-disabled=true],.link[aria-disabled],.link[disabled],a[aria-disabled=true],a[aria-disabled],a[disabled]{color:#ccc;cursor:not-allowed;pointer-events:none}.link:hover,a:hover{color:#000}.link-dashed{border:dashed;border-width:0 0 1px}.link-dashed:hover{color:#000}.red{color:#ff465c}ul{margin:0;padding:0}ul li{list-style-type:none}ol{margin:0;padding:0}.unordered-list{margin:1em 0;padding:0 0 0 16px}.unordered-list li{list-style:disc outside}.unordered-list li::marker{color:#1c257b}.unordered-list li+li{margin-top:1em}.OrderedListItem{align-items:baseline;display:flex;flex-wrap:wrap;padding:20px 0}.OrderedListItem__flatPillIcon{fill:#9400d3!important}.OrderedListItem__number{align-items:flex-start;background:#f5f6fc;border-radius:24px;box-sizing:border-box;color:#8d92bd;flex:0 0 48px;font-size:24px;font-weight:600;height:48px;line-height:48px;text-align:center}.OrderedListItem__text{box-sizing:border-box;flex:0 0 calc(100% - 48px);padding-left:22px}.caption{color:#000}.caption,.caption-frame{font-size:14px;font-weight:300}.caption-frame{border:1px solid #e0e1f3;border-radius:10px;box-sizing:border-box;color:#333;display:inline-block;line-height:1.4;padding:6px 12px 7px}.ux-money{white-space:nowrap}.ux-money:after{content:"\00A0\20BD";display:inline-block;font-size:85%;margin:-.125em 0 0;vertical-align:middle}.ux-commas>span:after{content:"\002C\0020"}.ux-commas>span:last-child:after{content:none}.ux-commas>span:nth-last-child(2):after{content:"\0020\0438\00A0"}.ux-commas-only>span:after{content:"\002C\0020"}.ux-commas-only>span:last-child:after{content:none}.ux-commas-only>div{display:inline}.ux-commas-only>div:after{content:"\002C\0020"}.ux-commas-only>div:last-child:after{content:none}hr[data-label]{background:#fff none no-repeat 0 0;background-image:linear-gradient(180deg,transparent 8px,#e0e1f3 8px 9px,transparent 9px);border:0;display:block;font-size:.875rem;font-weight:400;height:16px;line-height:15px;margin:1rem 0;position:static;text-align:center}hr[data-label]:before{background-color:inherit;content:attr(data-label);display:inline-block;padding:0 .25rem}.apteka-logo{color:#1c257b;font-weight:900;white-space:nowrap}.apteka-logo i{color:#ff465c;font-style:normal}body,html{background:#f5f6fc;margin:0;min-height:100%;padding:0;width:100%}#detach-button-host{display:none!important}body.unscroll{overflow:hidden;overflow-y:scroll;position:fixed}#app-container{display:contents}.body{box-sizing:border-box;max-width:100%;min-height:100vh;min-width:320px;padding-left:env(safe-area-inset-left);padding-right:env(safe-area-inset-right);position:relative;width:100%}@media (max-width:1024px){.body{padding-bottom:56px}}.body__header{height:75px;left:0;pointer-events:none;position:sticky;top:0;width:100%;z-index:4}@media (max-width:1024px){.body__header{height:100px;z-index:6}}.body__header--home-new-user{height:auto;position:relative}.body__header--home-new-user.body__header--sidebar{height:40px;overflow:hidden;position:sticky}.body__header--home-new-user+.body__wrapper{background:none;height:calc(82vh - 96px);min-height:calc(18vh + 350px)}.body__header--home-new-user+.body__wrapper .body__sidebar>div{padding-top:40px}.body__header-logo{display:block;height:24px;padding:26px 0 0 20px;width:120px}.body__header-logo .icon{display:bl ...
# <!--[--><!--APP-HEAD--><link href="/static/favicon.ico" rel="icon" sizes="any"/><link href="/static/favicon.svg" rel="icon" type="image/svg+xml"/><link href="/static/apple-touch-icon.png" rel="apple-touch-icon"/><link href="https://www.googletagmanager.com" rel="preconnect"/><!--[--><!--[--><link crossorigin="" href="https://api.apteka.ru" rel="preconnect"/><link href="https://api.apteka.ru" rel="dns-prefetch"/><!--]--><!--[--><link crossorigin="" href="https://images.apteka.ru" rel="preconnect"/><link href="https://images.apteka.ru" rel="dns-prefetch"/><!--]--><!--[--><link crossorigin="" href="https://static.apteka.ru" rel="preconnect"/><link href="https://static.apteka.ru" rel="dns-prefetch"/><!--]--><!--]--><title>Средства от аллергии – купить в Москве по низкой цене в интернет-аптеке Apteka.ru</title><meta content="width=device-width, height=device-height, user-scalable=no, viewport-fit=cover, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/><meta content="Средства от аллергии в наличии ⭐ низкие цены ⭐ Купить Средства от аллергии с доставкой до аптеки в Москве ⭐ в интернет-аптеке Apteka.ru ⭐ Сезонные скидки на Средства от аллергии, акции ⭐ и распродажи ⭐ только сегодня!" name="description"/><meta content="Средства от аллергии цена купить Москва" name="keywords"/><meta content="index, follow" name="robots"/><!-- --><meta content="Средства от аллергии в наличии ⭐ низкие цены ⭐ Купить Средства от аллергии с доставкой до аптеки в Москве ⭐ в интернет-аптеке Apteka.ru ⭐ Сезонные скидки на Средства от аллергии, акции ⭐ и распродажи ⭐ только сегодня!" property="og:description"/><meta content="Средства от аллергии – купить в Москве по низкой цене в интернет-аптеке Apteka.ru" property="og:title"/><meta content="https://images.apteka.ru/original_meta-logo.png" property="og:image"/><meta content="https://apteka.ru/category/allergy/" property="og:url"/><meta content="website" property="og:type"/><meta content="https://images.apteka.ru/original_meta-logo.png" property="og:image:secure_url"/><meta content="Apteka.ru" property="og:image:alt"/><meta content="image/png" property="og:image:type"/><meta content="600" property="og:image:width"/><meta content="600" property="og:image:height"/><meta content="uvlHo9MeUooFYnechabPXqkeiEJmrOtXWUT7AmzOJcgjieswnnRNC9fg99hq3wGH" name="zen-verification"/><meta content="aa9fa5d848caa475" name="yandex-verification"/><meta content="tix4i8mFs1b0MSssPppIEJaaVxR5gudXnkqJDS_qmsA" name="google-site-verification"/><link href="https://apteka.ru/category/allergy/" rel="canonical"/><!-- --><!-- --><link href="https://images.apteka.ru/original_meta-logo.png" rel="image_src"/><!--[--><!--]--><!--/APP-HEAD--><!--]-->
# <script>window.__INITIAL_STATE__ = {"supportPhone":"8 800 700 88 88","provinceCity":null,"selectedCity":{"id":"5e57803249af4c0001d64407","name":"Москва","prepositionalName":"Москве","state":"Москва","url":"moskva","centerCoords":{"latitude":55.73801816592129,"longitude":37.60896032379249},"areaRectangle":{"leftTopPoint":{"latitude":55.96399955,"longitude":37.268181},"rightBottomPoint":{"latitude":55.47877745,"longitude":37.980431}},"autoDestCount":2236,"regBodyAddress":"141400, ОБЛАСТЬ МОСКОВСКАЯ, ГОРОД ХИМКИ, ШОССЕ ВАШУТИНСКОЕ, 22","regBodyUid":"0032e72b-71f2-40ff-b457-13cd03af6422","nearCities":null,"deliveryDates":[{"shipTimeStart":"2024-07-08T23:00:00Z","shipTimeEnd":"2024-07-10T13:00:00Z","deadline":"2024-07-08T19:00:00Z"},{"shipTimeStart":"2024-07-09T03:00:00Z","shipTimeEnd":"2024-07-09T13:00:00Z","deadline":"2024-07-08T20:00:00Z"},{"shipTimeStart":"2024-07-09T23:00:00Z","shipTimeEnd":"2024-07-11T13:00:00Z","deadline":"2024-07-09T19:00:00Z"}]},"selectedShop":null,"ssrContext":{"env":{"API_INTERNAL_ENDPOINT":"http://api-other.aru:5001","SITE_ENVIRONMENT":"prod","API_EXTERNAL_ENDPOINT":"https://api.apteka.ru","SITE_KIND":"other"},"origin":"https://apteka.ru","userAgent":"python-requests/2.32.3","url":"/category/allergy/","host":"apteka.ru","httpStatus":null,"robot":false,"isTech":true,"headers":{"Accept":"*/*","Accept-Encoding":"gzip, deflate","User-Agent":"python-requests/2.32.3","Tx-Tls-Proto":"TLSv1.3","Tx-Tls-Cipher":"TLS_AES_128_GCM_SHA256","X-Bb-Ses-Durat":"-1","X-Bb-Ses-Fresh":"false","X-Bb-Ses-Valid":"false"},"clientIp":"46.147.234.235","trace":[]},"userAgentMobile":false,"vitamins":null,"prefetch":{"carousel_category-allergy":[]},"robot":false,"surveyModal":false,"progressiveDiscountPopup":false,"progressiveRecipe":false,"prescriptionsPopup":false,"confirmEmailNotifyPopup":false,"loading":false,"windowWidthType":"Desktop","catalogOverlayIsVisible":false,"referralPopup":false,"firstOrderDiscount":0,"buyTogetherPopup":false,"bannerClaimPopupId":null,"devHost":false,"medHost":true,"cacheloth":[],"errorPage":null,"yandexPanel":false,"utmMarks":null,"clientInfo":null,"head":{"title":"Средства от аллергии – купить в Москве по низкой цене в интернет-аптеке Apteka.ru","description":"Средства от аллергии в наличии ⭐ низкие цены ⭐ Купить Средства от аллергии с доставкой до аптеки в Москве ⭐ в интернет-аптеке Apteka.ru ⭐ Сезонные скидки на Средства от аллергии, акции ⭐ и распродажи ⭐ только сегодня!","keywords":"Средства от аллергии цена купить Москва","image":"https://images.apteka.ru/original_meta-logo.png","origin":"https://apteka.ru","robots":"index, follow","canonical":"https://apteka.ru/category/allergy/","prevLink":"","nextLink":"","expires":"","linkingData":[]},"auth":{"overlay":false,"status":{"error":false,"loading":false,"loaded":false,"phoneError":false,"passwordError":false,"networkError":false},"newUser":false},"session":{"id":"22eb6541-5e20-c161-d6be-5619f928a55e","newcomer":true},"user":{"login":null,"shadow":true,"info":null,"apiSid":"SCL_-2853e25y475N197P0504749u_50A963j217s912x808r831g375wY","deviceId":"1720454388929_7014e28806cd6","deviceTs":"1720454388932","fio":null,"gender":"NotSpecified","birthDate":null,"email":null,"emailVerified":false,"updated":1720454388972,"favoritesCount":0,"orders":[],"awaitingReview":null,"refineEmailPopup":false,"telegramChat":false,"allowCookies":true,"goodPreferences":{"cautionsFold":"None","pharmActFold":"None","pharmKinFold":"None","pharmDynFold":"None","structFold":"None","sideEffFold":"None","goodKitFold":"None","contraIndicFold":"None","drugInterFold":"None","dosageFold":"None","keepSpecialFold":"None","shortDescFold":"None","releaseFold":"None","dosDescFold":"None","indicFold":"None","overdoseFold":"None"}},"city":{"notify":false,"overlay":false,"default":{"id":"5e57803249af4c0001d64407","name":"Москва","prepositionalName":"Москве","state":"Москва","url":"moskva","centerCoords":{"latitude":55.73801816592129,"longitude":37.60896032379249},"areaRectangle":{"leftTopPoin ...
# </head><body><div id="app-container"><div class="body" id="app"><!--teleport start--><!--teleport end--><div class="body__header"><header class="SiteHeader"><!-- --><div class="SiteHeaderMain"><div class="SiteHeaderMain__logo"><div class="HeaderLogo"><a aria-label="Apteka.ru" class="link" href="/"><!--[--><svg alt="Apteka.ru" class="icon icon--logo"><use href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#logo" xlink:href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#logo"></use></svg><!--]--></a></div></div><div class="SiteHeaderMain__city"><button aria-label="Выбор города" class="HeaderCity" type="button"><svg class="icon icon--mappin"><use href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#mappin" xlink:href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#mappin"></use></svg><span>Москва</span></button></div><!-- --><div class="SiteHeaderMain__search"><div class="SearchBox"><!-- --><form action="/search/" autocomplete="off" class="SearchBox__input"><div><div class="SearchBox__input-icon"><svg class="icon icon--search"><use href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#search" xlink:href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#search"></use></svg></div><div class="SearchBox__input-input"><input disabled="" hidden="" spellcheck="false" type="text" value=""/><input autocomplete="off" id="apteka-search" name="q" placeholder="Введите название товара, заболевания или симптома" spellcheck="false" type="search"/></div><div class="SearchBox__input-speech"><button aria-label="Голосовой поиск" class="SpeechButton" disabled="" hidden="" type="button"><svg class="icon icon--microphone"><use href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#microphone" xlink:href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#microphone"></use></svg></button></div></div><button class="SearchBox__input-submit" type="submit"><span>Искать</span></button></form><!-- --><!-- --></div><div class="HintsToSearch"><span>Например:</span><div><ul><!--[--><li><a class="" href="/search/?q=%D0%BD%D0%B8%D0%BA%D0%BE%D1%80%D0%B5%D1%82%D1%82%D0%B5"><!--[--><!--]--></a></li><li><a class="" href="/search/?q=peptidpro"><!--[--><!--]--></a></li><li><a class="" href="/search/?q=%D0%BA%D0%B0%D0%BB%D0%B8%D1%8F+%D0%B9%D0%BE%D0%B4%D0%B8%D0%B4"><!--[--><!--]--></a></li><li><a class="" href="/search/?q=%D0%B4%D0%B5%D1%82%D1%81%D0%BA%D0%B8%D0%B5+%D0%BA%D0%BE%D0%BB%D0%B8%D0%BA%D0%B8"><!--[--><!--]--></a></li><li><a class="" href="/search/?q=%D0%B4%D0%BB%D1%8F+%D0%BB%D0%B5%D1%87%D0%B5%D0%BD%D0%B8%D1%8F+%D0%BC%D0%BE%D0%BB%D0%BE%D1%87%D0%BD%D0%B8%D1%86%D1%8B"><!--[--><!--]--></a></li><!--]--></ul></div></div><!-- --></div><!-- --><!-- --><div class="SiteHeaderMain__cart"><div class="ButtonIcon"><a aria-label="Корзина" class="ButtonIcon__link" href="/cart/"><span class="ButtonIcon-icon"><svg class="icon icon--nav_cart ButtonIcon__icon"><use href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#nav_cart" xlink:href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#nav_cart"></use></svg><!-- --><!-- --></span><span class="ButtonIcon-text">Корзина</span></a><!-- --></div></div></div><!-- --><!-- --></header></div><div class="body__wrapper"><div class="body__notify"></div><div aria-hidden="true" class="body__sidebar"><div><div class="sidebar"><div class="sidebar__inner"><div class="SidebarCatalog" style=""><div class="SidebarCatalog__tabs"><button disabled="" type="button"> Подобрать </button><button type="button"> Товары </button></div><div class="SidebarCatalog__back"><a class="" href="/"><!--[--><b>АЛЛЕРГИЯ</b><!--]--></a></div><div class="SidebarCatalog__list"><div class="SidebarCategoriesList"><ul aria-expanded="true"><!--[--><li><a class="" href="/category/allergy/pollenallergy/"><!--[--><b>Средства от аллергии</b><!--]--></a></li><!--]--></ul><!-- --></div></div></div><div class="sidebar-filters" is-new-search-page="false" style="display:none;"><div class="filters-popup__desktop-filters"><!--[--><div class="filters-popup__desktop-filter"><span c ...
# препарат</span></div><!--]--></div></div><div class="CardMini__purchase"><!--[--><div class="card-order-section"><!-- --><!--[--><!--[--><button class="light-button card-button-variants button-highlight"><!-- --><span class="light-button__label">Выбрать</span><!-- --><!-- --></button><!--]--><!--]--></div><!-- --><!--]--></div><!-- --><!-- --></div></li><!--]--><!-- --></ul></div></div><!-- --><!-- --></div></div><div class="ViewCatalogRoot__popular"><h2 class="carouselTitle">Самые покупаемые товары</h2><div class="ScrollBoxGoods"><div class="ScrollBoxGoods__list"><div><ul class="ScrollBoxGoods__stripe"><!--[--><li><div class="CardMini"><div class="CardMini__photo"><picture class="photopicture" data-webp="" style=""><source srcset="https://images.apteka.ru/medium_0496ccfa-d597-41d0-8720-84bc5976e666.webp" type="image/webp"/><img alt="." class="" draggable="false" height="300" src="https://images.apteka.ru/medium_0496ccfa-d597-41d0-8720-84bc5976e666.png" width="300"/><!-- --></picture><div class="CardMini__varik"><b>2 варианта</b></div></div><div class="CardMini__title">СУПРАСТИН ТАБЛЕТКИ</div><div class="CardMini__price"><!--[--><span>от </span><span class="moneyprice" data-size="17"><span class="moneyprice__content"><span class="moneyprice__roubles">142</span><!-- --></span><span class="moneyprice__currency">₽</span></span><!--]--></div><a class="CardMini__link" href="/product/suprastin-25-mg-20-sht-tabletki-5e326b1cf5a9ae00014099fa/"><!--[--><!--]--></a><div class="CardMini__labels"><div class="card-labels-block card-labels-block--mini"><!--[--><!--]--></div></div><div class="CardMini__purchase"><!--[--><div class="card-order-section"><!-- --><!--[--><!--[--><button class="light-button card-button-variants button-highlight"><!-- --><span class="light-button__label">Выбрать</span><!-- --><!-- --></button><!--]--><!--]--></div><!-- --><!--]--></div><!-- --><!-- --></div></li><li><div class="CardMini"><div class="CardMini__photo"><picture class="photopicture" data-webp="" style=""><source srcset="https://images.apteka.ru/medium
webp" type="image/webp"/><img alt="." class="" draggable="false" height="300" src="https://images.apteka.ru/medium_a8d958d8-5617-4382-b9d1-8d584d83f6f6.jpeg" width="300"/><!-- --></picture><!-- --></div><div class="CardMini__title">Супрастинекс 0,005/мл флакон капли 20 мл</div><div class="CardMini_ ...
# препарат</span></div><!--]--></div></div><div class="CardMini__purchase"><!--[--><div class="card-order-section"><!-- --><!--[--><!--[--><button class="light-button card-button-purchase button-highlight"><!--[--><svg class="icon icon--buy" style="margin-right:4px;"><use href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#buy" xlink:href="/svg/sprite.4ac067a8d6b4910be60b287fa7f779b2.svg#buy"></use></svg><!--]--><span class="light-button__label">Купить</span><!-- --><!-- --></button><!--]--><!--]--></div><!-- --><!--]--></div><!-- --><!-- --></div></li><li><div class="CardMini"><div class="CardMini__photo"><picture class="photopicture" data-webp="" style=""><source srcset="https://images.apteka.ru/medium_a58cb519-4caa-4a26-bcc9-4ecb84e394d0.webp" type="image/webp"/><img alt="." class="" draggable="false" height="300" src="https://images.apteka.ru/medium_a58cb519-4caa-4a26-bcc9-4ecb84e394d0.jpeg" width="300"/><!-- --></picture><div class="CardMini__varik"><b>4 варианта</b></div></div><div class="CardMini__title">ЦЕТИРИЗИН-ВЕРТЕКС</div><div class="CardMini__price"><!--[--><span>от </span><span class="moneyprice" data-size="17"><span class="moneyprice__content"><span class="moneyprice__roubles">63</span><!-- --></span><span class="moneyprice__currency">₽</span></span><!--]--></div><a class="CardMini__link" href="/product/czetirizin-verteks-10-mg-10-sht-tabletki-pokrytye-plenochnoj-obolochkoj-5e327158f5a9ae000140cad2/"><!--[--><!--]--></a><div class="CardMini__labels"><div class="card-labels-block card-labels-block--mini"><!--[--><!--]--></div></div><div class="CardMini__purchase"><!--[--><div class="card-order-section"><!-- --><!--[--><!--[--><button class="light-button card-button-variants button-highlight"><!-- --><span class="light-button__label">Выбрать</span><!-- --><!-- --></button><!--]--><!--]--></div><!-- --><!--]--></div><!-- --><!-- --></div></li><li><div class="CardMini"><div class="CardMini__photo"><picture class="photopicture" data-webp="" style=""><source srcset="https://images.apteka.ru/medium_08b078ff-c12b-4493-9aaa-cf0f2183a440.webp" type="image/webp"/><img alt="." class="" draggable="false" height="300" src="https://images.apteka.ru/medium_08b078ff-c12b-4493-9aaa-cf0f2183a440.jpeg" width="300"/><!-- --></picture><div class="CardMini__varik"><b>2 варианта</b></div></div><div class="CardMini__title">ЗОДАК</div><div class="CardMini__price"><!--[--><span>от </span><span class="moneyprice" data-size="17"><span class="moneyprice__content"><span class="moneyprice__roubles">128</span><!-- --></span><span class="moneyprice__currency">₽</span></span><!--]--></div><a class="CardMini__link" href="/product/zodak-10-mg-10-sht-tabletki-pokrytye-plenochnoj-obolochkoj-5e3277c7f5a9ae000140fb8c/"><!--[--><!--]--></a><div class="CardMini__labels"><div class="card-labels-block card-labels-block--mini"><!--[--><!--]--></div></div><div class="CardMini__purchase"><!--[--><div class="card-order-section"><!-- --><!--[--><!--[--><button class="light-button card-button-variants button-highlight"><!-- --><span class="light-button__label">Выбрать</span><!-- --><!-- --></button><!--]--><!--]--></div><!-- --><!--]--></div><!-- --><!-- --></div></li><li><div class="CardMini"><div class="CardMini__photo"><picture class="photopicture" data-webp="" style=""><source srcset="https://images.apteka.ru/medium_dec4de29-d0f1-4e97-9590-ce423733397f.webp" type="image/webp"/><img alt="." class="" draggable="false" height="300" src="https://images.apteka.ru/medium_dec4de29-d0f1-4e97-9590-ce423733397f.jpeg" width="300"/><!-- --></picture><div class="CardMini__varik"><b>2 варианта</b></div></div><div class="CardMini__title">БЛОГИР-3</div><div class="CardMini__price"><!--[--><span>от </span><span class="moneyprice" data-size="17"><span class="moneyprice__content"><span class="moneyprice__roubles">369</span><!-- --></span><span class="moneyprice__currency">₽</span></span><!--]--></div><a class="CardMini__link" href="/product/blogir-3-5-mg-10-sht-tabletki-dlya- ...

# %%
# Поиск по тегу <div>
result = soup.find_all('div', ('class','CardMini'))

# %%
len(result)
# Out:
# 0

# %%
print(result)
# Out:
# [<div class="CardMini"><div class="CardMini__photo"><picture class="photopicture" data-webp="" style=""><source srcset="https://images.apteka.ru/medium_407978a3-ea89-4ef3-8811-6000389903a0.webp" type="image/webp"/><img alt="." class="" draggable="false" height="300" src="https://images.apteka.ru/medium_407978a3-ea89-4ef3-8811-6000389903a0.jpeg" width="300"/><!-- --></picture><div class="CardMini__varik"><b>2 варианта</b></div></div><div class="CardMini__title">ЛОРАТАДИН</div><div class="CardMini__price"><!--[--><span>от </span><span class="moneyprice" data-size="17"><span class="moneyprice__content"><span class="moneyprice__roubles">65</span><!-- --></span><span class="moneyprice__currency">₽</span></span><!--]--></div><a class="CardMini__link" href="/product/loratadin-10-mg-10-sht-tabletki-5e326ad565b5ab000165268d/"><!--[--><!--]--></a><div class="CardMini__labels"><div class="card-labels-block card-labels-block--mini"><!--[--><!--]--></div></div><div class="CardMini__purchase"><!--[--><div class="card-order-section"><!-- --><!--[--><!--[--><button class="light-button card-button-variants button-highlight"><!-- --><span class="light-button__label">Выбрать</span><!-- --><!-- --></button><!--]--><!--]--></div><!-- --><!--]--></div><!-- --><!-- --></
webp" type="image/webp"/><img alt="." class="" draggable="false" height="300" src="https://images.apteka.ru/medium_a58cb519-4caa-4a26-bcc9-4ecb84e394d0.jpeg" width="300"/><!-- --></picture><div class="CardMini__varik"><b>4 варианта</b></div></div><div class="CardMini__title">ЦЕТИРИЗИН-ВЕРТЕКС</div><div class="CardMini__price"><!--[--><span>от </span><span class="moneyprice" data-size="17"><span class="moneyprice__content"><span class="moneyprice__roubles">63</span><!-- --></span><span class="moneyprice__currency">₽</span></span><!--]--></div><a class="CardMini__link" href="/product/czetirizin-verteks-10-mg-10-sht-tabletki-pokrytye-plenochnoj-obolochkoj-5e327158f5a9ae000140cad2/"><!--[--><!--]--></a><div class="CardMini__labels"><div class="card-labels-block card-labels-block--mini"><!--[--><!--]--></div></div><div class="CardMini__purchase"><!--[--><div class="card-order-section"><!-- --><!--[--><!--[--><button class="light-button card-button-variants button-highlight"><!-- --><span class="light-button__label">Выбрать</span><!-- --><!-- --></button><!--]--><!--]--></div><!-- --><!--]--></div><!-- --><!-- --></div>, <div class="CardMini"><div class="CardMini__photo"><picture class="photopicture" data-webp="" style=""><source srcset="https://images.apteka.ru/medium_08b078ff-c12b-4493-9aaa-cf0f2183a440.webp" type="image/webp"/><img alt="." class="" draggable="false" height="300" src="https://images.apteka.ru/medium_08b078ff-c12b-4493-9aaa-cf0f2183a440.jpeg" width="300"/><!-- --></picture><div class="CardMini__varik"><b>2 варианта</b></div></div><div class="CardMini__title">ЗОДАК</div><div class="CardMini__price"><!--[--><span>от </span><span class="moneyprice" data-size="17"><span class="moneyprice__content"><span class="moneyprice__roubles">128</span><!-- --></span><span class="moneyprice__currency">₽</span></span><!--]--></div><a class="CardMini__link" href="/product/zodak-10-mg-10-sht-tabletki-pokrytye-plenochnoj-obolochkoj-5e3277c7f5a9ae000140fb8c/"><!--[--><!--]--></a><div class="CardMini__labels"><div class="card-labels-block card-labels-block--mini"><!--[--><!--]--></div></div><div class="CardMini__purchase"><!--[--><div class="card-order-section"><!-- --><!--[--><!--[--><button class="light-button card-button-variants button-highlight"><!-- --><span class="light-button__label">Выбрать</span><!-- --><!-- --></button><!--]--><!--]--></div><!-- --><!--]--></div><!-- --><!-- --></div>, <div class="CardMini"><div class="CardMini__photo"><picture class="photopicture" data-webp="" style=""><source srcset="https://images.apteka.ru/medium_dec4de29-d0f1-4e97-9590-ce423733397f.webp" type="image/webp"/><img alt="." class="" draggable="false" height="300" src="https://images.apteka.ru/medium_dec4de29-d0f1-4e97-9590-ce423733397f.jpeg" width="300"/><!-- --></picture><div class="CardMini__varik"><b>2 варианта</b></div></div><div class="CardMini__title">БЛОГИР-3</div><div class="CardMini__price"><!--[--><span>от </span><span class="moneyprice" data-size="17"><span class="moneyprice__content"><span class="moneyprice__roubles">369</span><!-- --></span><span class="moneyprice__currency">₽</span></span><!--]--></div><a class="CardMini__link" href="/product/blogir-3-5-mg-10-sht-tabletki-dlya-rassasyvaniya-5e326fa ...

# %%
type(result)
# Out:
# bs4.element.ResultSet

# %% [markdown]
# ### Скрейпинг ссылок на каждый товар

# %%
# Первая часть ссылки
url_1 = 'https://apteka.ru'

# %%
# Извлечение списка относительных ссылок на товары
url_2 = []
for i in result:
  url_2.append(i.find('a').get('href'))

# %%
len(url_2)
# Out:
# 45

# %%
url_2
# Out:
# ['/product/loratadin-10-mg-10-sht-tabletki-5e326ad565b5ab000165268d/',
#  '/product/suprastin-25-mg-20-sht-tabletki-5e326b1cf5a9ae00014099fa/',
#  '/product/ajvest-kanon-5-mg-10-sht-tabletki-pokrytye-plenochnoj-obolochkoj-6294c8fc40212c41696f7f6e/',
#  '/product/feksofast-180-mg-10-sht-tabletki-pokrytye-plenochnoj-obolochkoj-5e3270deca7bdc0001931010/',
#  '/product/czetirizin-001ml-flakon-kapli-dlya-priema-vnutr-10-ml-5f0bfc9dcb7902000163f613/',
#  '/product/levoczetirizin-5-mg-10-sht-tabletki-pokrytye-plenochnoj-obolochkoj
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, user-scalable=no, height=device-height, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0, viewport-fit=cover" name="viewport"/>
# <title>Apteka.ru - С вашего IP замечена подозрительная активность</title>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Source+Sans+Pro:wght@400;600&amp;display=swap" rel="stylesheet"/>
# <link href="/static/Favicon.ico" rel="icon" type="image/x-icon"/>
# <style>.button,h1,p{font-family:'Source Sans Pro';line-height:150%}.button,body{align-items:center}h1,p{font-style:normal}.button:hover,h1{color:#1c257b}.button,.thumb{cursor:pointer}.slider::before,.thumb{box-sizing:border-box;position:absolute}.slider::before,.slider[data-loader],.slider[data-success],.thumb[data-stop]{pointer-events:none}.slider::before,.thumb::before{content:'';width:36px;height:36px;top:4px}body{display:flex;justify-content:flex-end;flex-direction:column;text-align:center;padding:20px;min-height:100vh;margin:0;background-color:#fff}footer{margin-top:20vh;margin-bottom:9vh}h1{font-weight:600;font-size:32px;margin:0 0 36px}.button,p{margin:0}p{font-weight:400;font-size:16px}.content>img{max-width:100%;margin-bottom:36px}p small{font-size:12px;color:#999}.button{font-size:14px;color:#4665d7;display:inline-flex;border:0;background:0 0;gap:6px;padding:4px 6px}.copy-icon[hidden]{display:none;visibility:hidden}.copy-icon[hidden]+.success-icon,.slider[data-error] .error,.slider[data-success] .success,.thumb .arrow{display:block}.slider-wrap[aria-hidden] .thumb,.slider[data-error] .arrow,.slider[data-loader] .arrow,.slider[data-success] .arrow,.success-icon,.thumb>img{display:none}.logo{margin-bottom:28px}.social__icon{position:relative;display:inline-block;width:34px;height:34px;border-radius:4px;background-color:#e0e1f3;margin-right:10px;transition:color .25s ease-out}.social__icon:hover{background-color:#c9cbe7}.social__icon:last-child{margin-right:0}.social__icon>img{position:absolute;top:50%;left:50%;transform:translate(-50%,-50%)}@media (max-width:800px){h1{font-size:20px}.content>img{width:220px}footer{margin-top:15vh}}.slider-wrap{margin:24px auto;transition:opacity .25s}.slider-wrap[aria-hidden]{visibility:hidden;pointer-events:none;opacity:0;z-index:-1}.slider-wrap p{margin-bottom:12px;line-height:1.2}.slider{position:relative;width:213px;height:44px;margin:0 auto;border-radius:91px;background:linear-gradient(260deg,rgba(208,229,251,.47) 4.68%,rgba(94,145,200,.36) 99.18%)}.slider::before{right:4px;border:2px dashed rgba(255,255,255,.5);border-radius:50%}.thumb{width:44px;height:44px;top:0;left:0;display:flex;align-items:center;justify-content:center}.thumb:hover::before,.thumb[data-stop]::before{outline-color:#d0d3ea}.thumb:hover::before{animation:.5s gelatine}@keyframes gelatine{from,to{transform:scale(1,1)}25%{transform:scale(.9,1.1)}50%{transform:scale(1.1,.9)}75%{transform:scale(.95,1.05)}}.thumb::before{position:absolute;left:4px;background-color:#fff;border-radius:50%;outline:transparent solid 2px}.thumb>img{position:relative;z-index:1}.thumb>img[hidden]{position:absolute;top:100vh;visibility:hidden;z-index:-1}.thumb .spinner{animation:.5s infinite paused spin}@keyframes spin{from{transform:rotate(0)}to{transform:rotate(360deg)}}.slider[data-loader] .spinner{display:block;animation-play-state:running}</style>
# </head>
# <body>
# <main>
# <h1>Подозрительная активность!</h1>
# <div class="content">
# <img alt="alert-cat" src="/432/static/Suspicious-Cat.png"/>
# <p>С вашего IP замечена подозрительная активность</p>
# <div aria-hidden="" class="slider-wrap">
# <p><small>Чтобы продолжить, зажмите и переместите стрелку до конца поля</small></p>
# <div class="slider">
# <div class="thumb">
# <img class="arrow" height="16" loading="lazy" src="/432/static/Arrow.png" width="16"/>
# <img class="spinner" height="16" loading="lazy" src="/432/static/Spinner.png" width="16"/>
# <img class="success" height="24" loading="lazy" src="/432/static/Valid.png" width="24"/>
# <img class="error" height="18" loading="lazy" src="/432/static/Error.png" width="18"/>
# </div>
# </div>
# </div>
# <div class="user-info">
# <p><small>ID запроса: <span id="RequestId"></span></small></p>
# <p><small>Ваш IP: <span id="Client-Ip"></span></small></p>
# </div>
# <button class="button" onclick="copyInfo()" type="button">
# <span>Копировать</span>
# <img class="copy-icon" height="24" src="/432/static/Copy.png" width="24"/>
# <img class="success-icon" height="24" src="/432/static/Success.png" width="24"/>
# </button>
# </div>
# </main>
# <footer>
# <div class="logo">
# <img src="/static/Logo.png"/>
# </div>
# <div class="social">
# <a class="social__icon" href="https://vk.com/aptekaru" target="_blank">
# <img src="/static/Vk-logo.png"/>
# </a>
# <a class="social__icon" href="https://ok.ru/apteka.ru" target="_blank">
# <img src="/static/Ok-Logo.png"/>
# </a>
# </div>
# </footer>
# <script>function startDrag(){return!1}function click(e){e.preventDefault();let t=document.querySelector(".slider"),n=document.querySelector(".spinner"),r=document.querySelector(".success"),i=document.querySelector(".error"),o=document.querySelector(".thumb"),a=n.getAttribute("src"),c=r.getAttribute("src"),s=i.getAttribute("src");n.removeAttribute("src"),n.removeAttribute("loading"),r.removeAttribute("src"),r.removeAttribute("loading"),i.removeAttribute("src"),i.removeAttribute("loading");let l=o.getBoundingClientRect(),u=e.clientX;"ontouchstart"in window&&(u=e.touches[0].clientX);let d=l.x,h=l.y+l.height+window.scrollY;function p(e){let n=e.clientX;"ontouchstart"in window&&(n=e.touches[0].clientX);let r=n-u,i=t.offsetWidth-o.offsetWidth;r<0&&(r=0),r>i&&(r=i),o.style.left=r+"px"}function f(e){let u=o.offsetLeft,m=t.offsetWidth-o.offsetWidth,y=t.offsetLeft+u+o.clientWidth,g=l.y+window.scrollY;if(u===m){let v="ontouchstart"in window?e.changedTouches[0].clientX:e.clientX,C="ontouchstart"in window?e.changedTouches[0].clientY:e.clientY,$={startX:d,startY:h,endX:y,endY:g},b={clientX:v,clientY:C};o.setAttribute("data-stop","");let k=e=>new Promise((t,n)=>setTimeout(t,e));k(1).then(async()=>(checkForkChosen($),n.setAttribute("src",a),t.setAttribute("data-loader",""),await k(3e3))).then(async()=>{let e=await checkEyeDamage(b);return!e||"boolean"!=typeof e||(r.setAttribute("src",c),t.removeAttribute("data-loader"),t.setAttribute("data-success",""),await k(1e3))}).then(async e=>{if(e){i.setAttribute("src",s),t.removeAttribute("data-loader"),t.setAttribute("data-error","");return}let n=new URLSearchParams(window.location.search),r=n.get("from");window.location=r})}else o.style.left="0px";"ontouchstart"in window?(document.removeEventListener("touchmove",p),document.removeEventListener("touchend",f)):(document.removeEventListener("mouseup",f),document.removeEventListener("mousemove",p))}"ontouchstart"in window?(document.addEventListener("touchmove",p),document.addEventListener("touchend",f)):(document.addEventListener("mousemove",p),document.addEventListener("mouseup",f))}document.addEventListener("DOMContentLoaded",async function(){let e=new URLSearchParams(window.location.search),t=e.get("rqid"),n=e.get("ip"),r=document.querySelector("#RequestId"),i=document.querySelector("#Client-Ip");r.textContent=t,i.textContent=n;let o=new Date().getTime(),a=document.querySelector("link[rel~='icon']");a||(a=document.createElement("link"),a.rel="icon",a.type="image/x-icon",document.head.appendChild(a)),a.href=`/static/Favicon.ico?v=${o%10}`;let c=document.querySelector(".slider-wrap"),s=await initClientChecking(),l={r:s};s&&await enterHata(l).finally(()=>{setTimeout(()=>{c.removeAttribute("aria-hidden")},2e3)});let u=document.querySelector(".thumb");u.addEventListener("dragstart",startDrag),"ontouchstart"in window?u.addEventListener("touchstart",click):u.addEventListener("mousedown",click)});const initClientChecking=async()=>fetch("https://api.apteka.ru/ClientInfo/InitParams",{method:"GET",headers:{"Content-Type":"application/json"}}).then(async r=>{if(200===r.status){let data=await r.json();if(!data)return null;let params=Object.entries(data||{}).map(([key,val])=>{let decodedStr,value;if("undefined"!=typeof atob&&(decodedStr=atob(val)),"undefined"!=typeof Buffer&&(decodedStr=Buffer.from(val,"base64").toString("binary")),decodedStr)try{value=eval(decodedStr)}catch(e){console.warn(e.message)}return`${key}:${value};`});if(params.length){let paramsStr=params.join(""),paramsBase64;if("undefined"!=typeof btoa&&(paramsBase64=btoa(paramsStr)),"undefined"!=typeof Buffer&&(paramsBase64=Buffer.from(paramsStr).toString("base64")),paramsBase64)return paramsBase64}return null}}).catch(e=>null),enterHata=async e=>fetch(`https://err.apteka.ru/Captcha/WelcomeToTheClub?${new URLSearchParams(e)}`,{method:"PUT",headers:{"Content-Type":"application/json"}}).then(e=>e).catch(e=>e),checkForkChosen=e=>fetch(`https://err.apteka.ru/Captcha/ChooseFork?${new URLSearchParams(e)}`, ...
# IP: ${n}`;navigator.clipboard.writeText(i),r.setAttribute("hidden",""),window.setTimeout(()=>r.removeAttribute("hidden"),2500)}function setCookie(e,t,n){let r=new Date;r.setTime(r.getTime()+n);let i="undefined"==typeof window?"":location.hostname,[,o,a]=/(\w+)\.(\w+)$/.exec(i)||[],c=o&&a?`${o}.${a}`:i;document.cookie=`${e}=${t};domain=.${c};path=/;expires=${r.toUTCString()};`}function readCookie(e){let t=document.cookie.match(RegExp("(?:^|; )"+e.replace(/([\.$?*|{}\(\)\[\]\\\/\+^])/g,"\\$1")+"=([^;]*)"));return t?decodeURIComponent(t[1]):void 0}</script>
# </body>
# </html>

# %%
# Парсинг названия товара
name = soup.find('h1', ('class', 'ViewProductPage__title')).text
name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 2
#       1 # Парсинг названия товара
# ----> 2 name = soup.find('h1', ('class', 'ViewProductPage__title')).text
#       3 name
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import re

# %%
form = soup.find('div', text=re.compile('Форма выпуска:'))

# %%
form.get_text(strip=True)[15:]
# Out:
# 'Tabletten'

# %%
# Парсинг формы выпуска
form = soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:]
form
# Out:
# 'Tabletten'

# %%
# Парсинг содержания
content = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
content
# Out:
# 'Содержание:\n    20\xa0St'

# %%
content = int(re.findall(r'\d+', content)[0])
content
# Out:
# 20

# %%
# Парсинг производителя
manufacturer = soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:]
manufacturer
# Out:
# 'Hexal AG'

# %%
# Парсинг цены товара
price = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
price
# Out:
# '5,19\xa0€'

# %%
type(price)
# Out:
# str

# %%
price = price.replace(',', '.')

# %%
price = re.sub(r'[^\d.]+', '', price)
price
# Out:
# '5.19'

# %%
price = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
price = price.replace(',', '.')
price = re.sub(r'[^\d.]+', '', price)
float(price)
# Out:
# 5.19

# %%
float(price)

# %% [markdown]
# ### Объединяем все вместе - скрейпинг и парсинг информации о всех товарах одной страницы

# %%
# Пустые списки, которые будут содержать соответствующие данные: название, цена, форма выпуска, содержание, производитель
name =[]
price =[]
form = []
content =[]
manufacturer =[]

# %%
# Создание пустого словаря, который будет содержать все получаемые данные
output ={}

# %%
# Цикл по списку ссылок на товары
for i in url_joined:
  response = requests.get(i)
  soup = BeautifulSoup(response.content, 'html.parser')

# Парсинг названия товара. Обработка исключения: добавляем пустую строку.
  try:
    name.append(soup.find('h1', ('class', 'h2 mt-0 sm:mb-6')).text)
  except:
    name.append('')

# Парсинг цены товара. 
  try:
    p = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
    p = p.replace(',', '.')
    p = float(re.sub(r'[^\d.]+', '', p))
    price.append(p)
  except:
    price.append('')

# Парсинг формы выпуска товара.
  try:
    form.append(soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:])
  except:
    form.append('')

# Парсинг содержания (веса) товара.  
  try:  
    cont = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
    cont = int(re.findall(r'\d+', cont)[0])
    content.append(cont)
  except:
    content.append('')

# Парсинг производителя товара.
  try:
    manufacturer.append(soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:])
  except:
    manufacturer.append('')

# Записываем данные в словарь
  output = {'Name' : name, 'Price' : price, 'Form' : form, 'Content' : content, 'Manufacturer' : manufacturer}

# %%
output
# Out:
# {'Name': ['Lorano akut Tabletten 20\xa0St',
#   'Desloratadin-ratiopharm 5 mg Filmtabletten 100\xa0St',
#   'Allegra Allergietabletten 20 mg Tabletten 50\xa0St',
#   'Vividrin Mometason Heuschnupfennasenspray 18\xa0g',
#   'Desloratadin Heumann 5 mg Filmtabletten 50\xa0St',
#   'AllergoPax Milbenspray 500\xa0ml',
#   'Ipalat Hydro Med Lutschpastillen 30\xa0St',
#   'Momekort 50 µg/Sprühstoß Nasenspray, Susp.140 für Erwachsene 18\xa0g',
#   '',
#   'Allegra Allergietabletten 20 mg Tabletten 6\xa0St',
#   'Allegra Allergietabletten 20 mg Tabletten 20\xa0St',
#   'MometaDex 50 µg/Sprühstoß Nasenspray 18\xa0g',
#   'MometaDex 50 µg/Sprühstoß Nasenspray 10\xa0g',
#   'Tavegil Tabletten 60\xa0St',
#   'Allergodil akut forte 1,5 mg/ml Nasenspray Lösung 10\xa0ml',
#   'ALLERGO-AZELIND von DoppelherzPharma 6\xa0ml',
#   'ALLERGO-MOMELIND von DoppelherzPharma 18\xa0g',
#   'ALLERGO-MOMELIND von DoppelherzPharma 10\xa0g',
#   'Astragalus Pro 500/50-Kapseln 60\xa0St',
#   'Tetesept Meerwasser Nasenspülsalz 20\xa0St',
#   'Levocetirizin Fairmed 5 mg Filmtabletten 100\xa0St',
#   'Levocetirizin Fairmed 5 mg Filmtabletten 20\xa0St',
#   'Levocetirizin Fairmed 5 mg Filmtabletten 10\xa0St',
#   'Daosin Tabletten 120\xa0St'],
#  'Price': [5.19,
#   18.89,
#   18.79,
#   12.69,
#   21.59,
#   49.95,
#   6.2,
#   18.2,
#   '',
#   4.91,
#   8.49,
#   6.69,
#   4.29,
#   18.97,
#   9.69,
#   6.2,
#   8.28,
#   5.47,
#   29.95,
#   5.52,
#   18.2,
#   4.68,
#   6.62,
#   92.59],
#  'Form': ['Tabletten',
#   'Filmtabletten',
#   'Tabletten',
#   'Nasenspray',
#   'Filmtabletten',
#   'Lösung',
#   'Pastillen',
#   'Nasenspray',
#   '',
#   'Tabletten',
#   'Tabletten',
#   'Nasenspray',
#   'Nasenspray',
#   'Tabletten',
#   'Nasenspray',
#   'Augentropfen',
#   'Nasendosierspray',
#   'Nasendosierspray',
#   'Kapseln',
#   'Salz',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Tabletten'],
#  'Content': [20,
#   100,
#   50,
#   18,
#   50,
#   500,
#   30,
#   18,
#   '',
#   6,
#   20,
#   18,
#   10,
#   60,
#   10,
#   6,
#   18,
#   10,
#   60,
#   20,
#   100,
#   20,
#   10,
#   120],
#  'Manufacturer': ['Hexal AG',
#   'ratiopharm GmbH',
#   'A. Nattermann & Cie GmbH',
#   'Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'Doromed GmbH',
#   'Dr. Pfleger Arzneimittel GmbH',
#   'DERMAPHARM AG',
#   '',
#   'A. Nattermann & Cie GmbH',
#   'A. Nattermann & Cie GmbH',
#   'Dexcel Pharma GmbH',
#   'Dexcel Pharma GmbH',
#   'STADA Consumer Health Deutschland GmbH',
#   'Viatris Healthcare GmbH',
#   'Queisser Pharma GmbH & Co. KG',
#   'Queisser Pharma GmbH & Co. KG',
#   'Queisser Pharma GmbH & Co. KG',
#   'Zein Pharma - Germany GmbH',
#   'Merz Consumer Care GmbH',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'STADA Consumer Health Deutschland GmbH']}

# %%
# Создание pandas dataframe
df = pd.DataFrame(output)

# %%
df
# Out:
#                                                  Name  Price  \
# 0                         Lorano akut Tabletten 20 St   5.19
# 1   Desloratadin-ratiopharm 5 mg Filmtabletten 100 St  18.89
# 2     Allegra Allergietabletten 20 mg Tabletten 50 St  18.79
# 3      Vividrin Mometason Heuschnupfennasenspray 18 g  12.69
# 4       Desloratadin Heumann 5 mg Filmtabletten 50 St  21.59
# 5                       AllergoPax Milbenspray 500 ml  49.95
# 6              Ipalat Hydro Med Lutschpastillen 30 St    6.2
# 7   Momekort 50 µg/Sprühstoß Nasenspray, Susp.140 ...   18.2
# 8
# 9      Allegra Allergietabletten 20 mg Tabletten 6 St   4.91
# 10    Allegra Allergietabletten 20 mg Tabletten 20 St   8.49
# 11          MometaDex 50 µg/Sprühstoß Nasenspray 18 g   6.69
# 12          MometaDex 50 µg/Sprühstoß Nasenspray 10 g   4.29
# 13                            Tavegil Tabletten 60 St  18.97
# 14  Allergodil akut forte 1,5 mg/ml Nasenspray Lös...   9.69
# 15          ALLERGO-AZELIND von DoppelherzPharma 6 ml    6.2
# 16         ALLERGO-MOMELIND von DoppelherzPharma 18 g   8.28
# 17         ALLERGO-MOMELIND von DoppelherzPharma 10 g   5.47
# 18                Astragalus Pro 500/50-Kapseln 60 St  29.95
# 19            Tetesept Meerwasser Nasenspülsalz 20 St   5.52
# 20    Levocetirizin Fairmed 5 mg Filmtabletten 100 St   18.2
# 21     Levocetirizin Fairmed 5 mg Filmtabletten 20 St   4.68
# 22     Levocetirizin Fairmed 5 mg Filmtabletten 10 St   6.62
# 23                            Daosin Tabletten 120 St  92.59
#
#                 Form Content                              Manufacturer
# 0          Tabletten      20                                  Hexal AG
# 1      Filmtabletten     100                           ratiopharm GmbH
# 2          Tabletten      50                  A. Nattermann & Cie GmbH
# 3         Nasenspray      18  Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH
# 4      Filmtabletten      50     HEUMANN PHARMA GmbH & Co. Generica KG
# 5             Lösung     500                              Doromed GmbH
# 6          Pastillen      30             Dr. Pfleger Arzneimittel GmbH
# 7         Nasenspray      18                             DERMAPHARM AG
# 8
# 9          Tabletten       6                  A. Nattermann & Cie GmbH
# 10         Tabletten      20                  A. Nattermann & Cie GmbH
# 11        Nasenspray      18                        Dexcel Pharma GmbH
# 12        Nasenspray      10                        Dexcel Pharma GmbH
# 13         Tabletten      60    STADA Consumer Health Deutschland GmbH
# 14        Nasenspray      10                   Viatris Healthcare GmbH
# 15      Augentropfen       6             Queisser Pharma GmbH & Co. KG
# 16  Nasendosierspray      18             Queisser Pharma GmbH & Co. KG
# 17  Nasendosierspray      10             Queisser Pharma GmbH & Co. KG
# 18           Kapseln      60                Zein Pharma - Germany GmbH
# 19              Salz      20                   Merz Consumer Care GmbH
# 20     Filmtabletten     100     HEUMANN PHARMA GmbH & Co. Generica KG
# 21     Filmtabletten      20     HEUMANN PHARMA GmbH & Co. Generica KG
# 22     Filmtabletten      10     HEUMANN PHARMA GmbH & Co. Generica KG
# 23         Tabletten     120    STADA Consumer Health Deutschland GmbH

# %% [markdown]
# ## Скрейпинг нескольких страниц

# %%
name =[]
price =[]
form = []
content =[]
manufacturer =[]
output = {}

url_1 = 'https://www.aptekaru.de'
url = 'https://www.aptekaru.de/online-shop/allergie-heuschnupfen'

while True:
  
  page = requests.get(url)
  soup = BeautifulSoup(page.content, 'html.parser')
  next_page_link = soup.find('a', ('class', 'arrow next'))
  result = soup.find_all('div', ('class','product-box-container'))

  url_2 = []
  for i in result:
    for link in i.find_all('div', ('class','product-box__image')):
      url_2.append(link.find('a').get('href'))
  
  url_joined = []

  for link in url_2:
    url_joined.append(urllib.parse.urljoin(url_1, link))
  
  for i in url_joined:
    response = requests.get(i)

    soup = BeautifulSoup(response.content, 'html.parser')

    # Парсинг названия товара. Обработка исключения: добавляем пустую строку.
    try:
      name.append(soup.find('h1', ('class', 'h2 mt-0 sm:mb-6')).text)
    except:
      name.append('')

    # Парсинг цены товара. 
    try:
      p = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
      p = p.replace(',', '.')
      p = float(re.sub(r'[^\d.]+', '', p))
      price.append(p)
    except:
      price.append('')

    # Парсинг формы выпуска товара.
    try:
      form.append(soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:])
    except:
      form.append('')

    # Парсинг содержания (веса) товара.  
    try:  
      cont = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
      cont = int(re.findall(r'\d+', cont)[0])
      content.append(cont)
    except:
      content.append('')

    # Парсинг производителя товара.
    try:
      manufacturer.append(soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:])
    except:
      manufacturer.append('')

    output = {'Name' : name, 'Price' : price, 'Form' : form, 'Content' : content, 'Manufacturer' : manufacturer}

  if not next_page_link:
    break
  
  url = url_1 + next_page_link['href']

# %%
df = pd.DataFrame(output)
df
# Out:
#                                                   Name  Price           Form  \
# 0                          Lorano akut Tabletten 20 St   5.19      Tabletten
# 1    Desloratadin-ratiopharm 5 mg Filmtabletten 100 St  18.89  Filmtabletten
# 2      Allegra Allergietabletten 20 mg Tabletten 50 St  18.79      Tabletten
# 3       Vividrin Mometason Heuschnupfennasenspray 18 g  12.69     Nasenspray
# 4        Desloratadin Heumann 5 mg Filmtabletten 50 St  21.59  Filmtabletten
# ..                                                 ...    ...            ...
# 130  Levocetirizin - 1 A Pharma 5 mg Filmtabletten ...  20.73  Filmtabletten
# 131  Levocetirizin - 1 A Pharma 5 mg Filmtabletten ...  17.75  Filmtabletten
# 132  Levocetirizin - 1 A Pharma 5 mg Filmtabletten ...   8.26  Filmtabletten
# 133  Levocetirizin HEXAL bei Allergien 5 mg Filmtab...  25.96  Filmtabletten
# 134  Levocetirizin HEXAL bei Allergien 5 mg Filmtab...  15.49  Filmtabletten
#
#     Content                              Manufacturer
# 0        20                                  Hexal AG
# 1       100                           ratiopharm GmbH
# 2        50                  A. Nattermann & Cie GmbH
# 3        18  Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH
# 4        50     HEUMANN PHARMA GmbH & Co. Generica KG
# ..      ...                                       ...
# 130     100                           1 A Pharma GmbH
# 131      50                           1 A Pharma GmbH
# 132      20                           1 A Pharma GmbH
# 133     100                                  Hexal AG
# 134      50                                  Hexal AG
#
# [135 rows x 5 columns]

# %%
df.to_csv('remedies.csv')
